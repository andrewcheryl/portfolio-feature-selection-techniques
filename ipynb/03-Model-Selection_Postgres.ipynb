# %%
cd /home/jovyan/Documents/dsi_plus/Projects/project_3 - Madelon_feature_selection
# Out:
# /home/jovyan/Documents/dsi_plus/Projects/project_3 - Madelon_feature_selection

# %%
#Import standard modules
# %run lib/__init__.py
# %matplotlib inline

# %% [markdown]
# ### Project 3: Madelon Dataset - Feature Selection + Classification
#
#
# ### Step 3 - Model Selection

# %%
modelScores=pd.DataFrame()
pickle_f=Pickle_files()
datafiles=pickle_f.read_datafiles()
#datafiles

# %%
X=pd.read_pickle(datafiles['Sample1'][2]) #X_train
y=pd.read_pickle(datafiles['Sample1'][4]) #y_train

# %%
bf=pickle_f.load_SBF()
bf.sort_values('best_test_score', ascending=False)
# Out:
#                                           best_params  best_test_score  \
# 8                                      {'skb__k': 10}         0.811781
# 20  {'sfm__estimator': LogisticRegression(C=100.0,...         0.810959
# 0                                      {'skb__k': 15}         0.808554
# 12  {'sfm__estimator': LogisticRegression(C=100.0,...         0.805974
# 4                                      {'skb__k': 15}         0.803959
# 16  {'sfm__estimator': LogisticRegression(C=10.0, ...         0.789898
# 3                                      {'skb__k': 15}         0.767142
# 11                                     {'skb__k': 10}         0.765890
# 23  {'sfm__estimator': LogisticRegression(C=10.0, ...         0.765616
# 19  {'sfm__estimator': LogisticRegression(C=100.0,...         0.765188
# 7                                      {'skb__k': 15}         0.762594
# 15  {'sfm__estimator': LogisticRegression(C=100.0,...         0.755872
# 22  {'sfm__estimator': LogisticRegression(C=1000.0...         0.737123
# 10                                     {'skb__k': 10}         0.732877
# 6                                      {'skb__k': 15}         0.729147
# 18  {'sfm__estimator': LogisticRegression(C=1000.0...         0.726826
# 14  {'sfm__estimator': LogisticRegression(C=100.0,...         0.725866
# 2                                      {'skb__k': 15}         0.722743
# 21  {'sfm__estimator': LogisticRegression(C=100.0,...         0.684110
# 17  {'sfm__estimator': LogisticRegression(C=100.0,...         0.683686
# 13  {'sfm__estimator': LogisticRegression(C=100.0,...         0.679701
# 5                                      {'skb__k': 15}         0.657201
# 1                                      {'skb__k': 15}         0.647794
# 9                                      {'skb__k': 20}         0.635753
#
#     dataset                                         featSelect    model  \
# 8   Sample3  [269, 315, 341, 681, 701, 736, 769, 808, 829, ...  SKB_KNN
# 20  Sample3  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...  SFM_KNN
# 0   Sample1  [257, 269, 315, 336, 341, 504, 526, 681, 701, ...  SKB_KNN
# 12  Sample1  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...  SFM_KNN
# 4   Sample2  [257, 269, 315, 336, 341, 504, 681, 701, 724, ...  SKB_KNN
# 16  Sample2  [257, 269, 315, 336, 341, 395, 504, 526, 639, ...  SFM_KNN
# 3   Sample1  [257, 269, 315, 336, 341, 504, 526, 681, 701, ...  SKB_SVC
# 11  Sample3  [269, 315, 341, 681, 701, 736, 769, 808, 829, ...  SKB_SVC
# 23  Sample3  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...  SFM_SVC
# 19  Sample2  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...  SFM_SVC
# 7   Sample2  [257, 269, 315, 336, 341, 504, 681, 701, 724, ...  SKB_SVC
# 15  Sample1  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...  SFM_SVC
# 22  Sample3  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...   SFM_DT
# 10  Sample3  [269, 315, 341, 681, 701, 736, 769, 808, 829, ...   SKB_DT
# 6   Sample2  [257, 269, 315, 336, 341, 504, 681, 701, 724, ...   SKB_DT
# 18  Sample2  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...   SFM_DT
# 14  Sample1  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...   SFM_DT
# 2   Sample1  [257, 269, 315, 336, 341, 504, 526, 681, 701, ...   SKB_DT
# 21  Sample3  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...   SFM_LR
# 17  Sample2  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...   SFM_LR
# 13  Sample1  [257, 269, 308, 315, 336, 341, 395, 504, 526, ...   SFM_LR
# 5   Sample2  [257, 269, 315, 336, 341, 504, 681, 701, 724, ...   SKB_LR
# 1   Sample1  [257, 269, 315, 336, 341, 504, 526, 681, 701, ...   SKB_LR
# 9   Sample3  [257, 269, 315, 336, 341, 395, 494, 504, 526, ...   SKB_LR
#
#     n_featSelect
# 8             10
# 20            20
# 0             15
# 12            20
# 4             15
# 16            18
# 3             15
# 11            10
# 23            19
# 19            20
# 7             15
# 15            20
# 22            20
# 10            10
# 6             15
# 18            20
# 14            20
# 2             15
# 21            20
# 17            20
# 13            20
# 5             15
# 1             15
# 9             20

# %%
bf['featSelect'].value_counts()
# Out:
# [257, 269, 315, 336, 341, 504, 681, 701, 724, 736, 769, 808, 829, 867, 920]                             1
# [269, 315, 341, 681, 701, 736, 769, 808, 829, 920]                                                      1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [269, 315, 341, 681, 701, 736, 769, 808, 829, 920]                                                      1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 315, 336, 341, 395, 494, 504, 526, 646, 667, 681, 701, 724, 736, 769, 808, 829, 867, 920]    1
# [257, 269, 315, 336, 341, 504, 526, 681, 701, 736, 769, 808, 829, 867, 920]                             1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [269, 315, 341, 681, 701, 736, 769, 808, 829, 920]                                                      1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 315, 336, 341, 504, 681, 701, 724, 736, 769, 808, 829, 867, 920]                             1
# [257, 269, 315, 336, 341, 504, 681, 701, 724, 736, 769, 808, 829, 867, 920]                             1
# [257, 269, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 829, 867, 920, 956]              1
# [257, 269, 315, 336, 341, 504, 681, 701, 724, 736, 769, 808, 829, 867, 920]                             1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 315, 336, 341, 504, 526, 681, 701, 736, 769, 808, 829, 867, 920]                             1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 315, 336, 341, 504, 526, 681, 701, 736, 769, 808, 829, 867, 920]                             1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 315, 336, 341, 504, 526, 681, 701, 736, 769, 808, 829, 867, 920]                             1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 639, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]    1
# [257, 269, 308, 315, 336, 341, 395, 504, 526, 681, 701, 724, 736, 769, 808, 829, 867, 920, 956]         1
# Name: featSelect, dtype: int64

# %%
from collections import Counter
allf=[]

for i in range(11):
    allf=allf+bf['featSelect'][i].tolist()

con=Counter()
for n in allf :
    con[n]+=1

feat_count=pd.DataFrame(con, index=['countF'])
feat_count.T.plot.bar()
plt.title('Samples: No. of times features included in best set')
plt.tight_layout()
plt.savefig('./images/03-Model_Selection-sample1-bf.jpg')

# %%
#best features selected
mask_all=feat_count.T.countF>0
sbf_all=(feat_count.T[mask_all].index)

mask_10=feat_count.T.countF>8
sbf_ten=(feat_count.T[mask_10].index)

mask_5=feat_count.T.countF>10
sbf_5=(feat_count.T[mask_5].index)
sbf_all
# Out:
# Int64Index([257, 269, 315, 336, 341, 395, 494, 504, 526, 646, 667, 681, 701,
#             724, 736, 769, 808, 829, 867, 920],
#            dtype='int64')

# %%
sbf_ten
# Out:
# Int64Index([257, 269, 315, 336, 341, 504, 681, 701, 736, 769, 808, 829, 867,
#             920],
#            dtype='int64')

# %%
sbf_5
# Out:
# Int64Index([269, 315, 341, 681, 701, 736, 769, 808, 829, 920], dtype='int64')

# %% [markdown]
# Checkout PCA -  use all

# %%
X_L=X[sbf_all].shape[1]
pca=PCA()
Xp=pca.fit_transform(X[sbf_all])
Xp_df=pd.DataFrame(Xp, columns=['PC'+str(1+i) for i in range(X_L)])
Xp_df.head(5)
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -5.902849 -0.635085  2.542635  0.239577 -1.188596 -0.255409  0.472276
# 1 -1.330172 -1.622546 -4.934483 -0.827681  2.649134  0.110854 -0.749246
# 2  0.911330 -3.009436 -3.661708 -1.220922  0.823151  0.703645  0.921440
# 3  2.268538 -2.353246  2.982261  0.102395  0.847377  0.429935  0.425931
# 4 -0.749237  4.713872 -4.803881  2.928732 -2.487172  1.396364 -0.116692
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0  0.583820 -0.005827 -0.014329 -0.014413 -0.009754 -0.008830 -0.001148
# 1 -0.038373 -0.018234  0.027978 -0.001143 -0.020107  0.001174 -0.003755
# 2 -1.556899 -0.014548  0.012293 -0.007379 -0.022182  0.002176 -0.001367
# 3 -0.598295 -0.005599 -0.016250  0.009958 -0.014175 -0.000815  0.003277
# 4 -0.188873 -0.015617 -0.026821 -0.008489  0.014215  0.007162  0.003568
#
#        PC15      PC16      PC17      PC18      PC19      PC20
# 0 -0.003315  0.001423  0.003117  0.001816 -0.001195 -0.000383
# 1 -0.003869  0.003873 -0.002866  0.002151 -0.001892 -0.001137
# 2 -0.004490  0.002783  0.002855  0.001627 -0.001320 -0.001384
# 3 -0.008987  0.000284 -0.001360  0.001417 -0.000571 -0.000439
# 4 -0.019371 -0.001153  0.001903 -0.006968  0.006374  0.001004

# %%
fig=plt.figure(figsize=(10,5))
for i in range(9):
    fig.add_subplot(3,3,1+i)
    plt.plot(pca.components_[i])
    plt.xlabel('feature')
    plt.title('PC'+str(i+1))
    
plt.tight_layout()
plt.savefig('./images/03-Model_Selection-sample1-pc.jpg')

# %%
Xp_var=pd.DataFrame(pca.explained_variance_ratio_, columns=['var_ratio'])
Xp_var['cum_var']=Xp_var.var_ratio.cumsum()
Xp_var.sort_values('var_ratio',ascending=False).plot()
plt.axhline(Xp_var.loc[5,'cum_var'],c='r',ls='--', label='sum for first 5 PC')
plt.ylabel('explained variance')
plt.xlabel('PC')
plt.legend()
plt.title('Explained Variance by PC')
plt.savefig('./images/03-Model_Selection-sample1-pc_var.jpg')

# %%
fig=plt.figure(figsize=(15,6))
fig.add_subplot(1,3,1)
plt.scatter(Xp_df.PC1,Xp_df.PC2, c=y, cmap='magma')
plt.xlabel('PC1')
plt.ylabel('PC2')
fig.add_subplot(1,3,2)
plt.scatter(Xp_df.PC2,Xp_df.PC3, c=y, cmap='magma')
plt.xlabel('PC2')
plt.ylabel('PC3')
fig.add_subplot(1,3,3)
plt.scatter(Xp_df.PC3,Xp_df.PC4, c=y, cmap='magma')
plt.xlabel('PC3')
plt.ylabel('PC4')
fig.tight_layout()
plt.savefig('./images/03-Model_Selection-sample1-pc_corr.jpg')

# %% [markdown]
# ### 2. Choose best model

# %%
def sbf_benchmark_grs(X,y,clf, param_clf):
    '''build pipelines for each classifier '''
    
    
    
    pipe=Pipeline(steps=[('scaler' , StandardScaler()),
                         ('clf' , clf)
                            ])
        
    grsCV=GridSearchCV(pipe,param_grid=param_clf,n_jobs=-1, verbose=1,\
                           cv=StratifiedShuffleSplit(n_splits=5, test_size=.2))
                          
    grsCV.fit(X,y.squeeze())
    
    
    return pd.DataFrame(grsCV.cv_results_)

# %%
def sbf_benchmark_grs_pc(X,y,clf, param_clf):
    '''build pipelines for each classifier '''
    
    
    pipe=Pipeline(steps=[('scaler' , StandardScaler()),
                         ('pca' , PCA()),
                         ('clf' , clf)
                            ])
        
    grsCV=GridSearchCV(pipe,param_grid=param_clf,n_jobs=-1, verbose=1,\
                           cv=StratifiedShuffleSplit(n_splits=5, test_size=.2))
                          
    grsCV.fit(X,y.squeeze())
    
    
    return pd.DataFrame(grsCV.cv_results_)

# %%
def run_models(ds, X , y, clf ,param_clf,pca=0 ):
    
    model_score=pd.DataFrame()
    masks={'all':sbf_all, 'top5':sbf_5 ,'top10': sbf_ten}
    
    for i,m in masks.items():
        if pca==0:
            results=sbf_benchmark_grs(X[m],y,clf, param_clf)
        else:
            results=sbf_benchmark_grs_pc(X[m],y,clf, param_clf)
        
        results['Dataset']=ds
        results['featset']=i
        
        if model_score.shape==(0,0):
            model_score=results
        else:
            model_score=pd.concat([model_score,results],axis=0, ignore_index=True)
    
    return model_score

# %% [markdown]
# ### 3. Score datasets

# %%
model_scores=pd.DataFrame()

# %% [markdown]
# Optimize KNN

# %%
clfk=KNeighborsClassifier()
param_clfk=({'clf__n_neighbors': np.arange(1,10,1)})

# %%
# %%time
ds='Sample1_KNN'
results=run_models(ds,X,y,clfk, param_clfk,pca=0)

model_scores=results
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    8.1s finished
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    1.8s finished
# CPU times: user 460 ms, sys: 160 ms, total: 620 ms
# Wall time: 13 s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    2.5s finished

# %%
# %%time
ds='Sample1_KNN_PC'
results=run_models(ds,X,y,clfk, param_clfk,pca=1)

model_scores=pd.concat([model_scores,results],axis=0, ignore_index=True)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    7.1s finished
# [Parallel(n_jobs=-1)]: Done  38 out of  45 | elapsed:    1.9s remaining:    0.3s
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    2.1s finished
# [Parallel(n_jobs=-1)]: Done  38 out of  45 | elapsed:    2.6s remaining:    0.5s
# CPU times: user 530 ms, sys: 480 ms, total: 1.01 s
# Wall time: 12.6 s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    2.9s finished

# %% [markdown]
# Optimize Logistic Regression

# %%
clfLr=LogisticRegression(random_state=42)
param_clfLr=({'clf__C':np.logspace(-3,3,7),
             'clf__penalty':['l2','l1']})

# %%
# %%time
ds='Sample1_LogR'
results=run_models(ds,X,y,clfLr, param_clfLr,pca=0)

model_scores=pd.concat([model_scores,results],axis=0, ignore_index=True)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:   53.7s finished
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:   48.2s finished
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:   48.5s finished
# CPU times: user 9.51 s, sys: 250 ms, total: 9.76 s
# Wall time: 2min 39s

# %%
# %%time
ds='Sample1_LogR_PC'
results=run_models(ds,X,y,clfLr, param_clfLr,pca=1)

model_scores=pd.concat([model_scores,results],axis=0, ignore_index=True)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    2.5s finished
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    1.5s finished
# CPU times: user 520 ms, sys: 670 ms, total: 1.19 s
# Wall time: 6.2 s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    1.7s finished

# %% [markdown]
# Optimize DecisionTree

# %%
clfDt=DecisionTreeRegressor(random_state=42)
param_clfDt=({'clf__max_depth':[5,6,7,8,9,10,None],
             'clf__min_samples_split':[2,3,4]})

# %%
# %%time
ds='Sample1_Dt'
results=run_models(ds,X,y,clfDt, param_clfDt,pca=0)

model_scores=pd.concat([model_scores,results],axis=0, ignore_index=True)
# Out:
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    2.2s finished
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    1.3s finished
# CPU times: user 630 ms, sys: 230 ms, total: 860 ms
# Wall time: 5.58 s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    1.6s finished

# %%
# %%time
ds='Sample1_Dt_PC'
results=run_models(ds,X,y,clfDt, param_clfDt,pca=1)

model_scores=pd.concat([model_scores,results],axis=0, ignore_index=True)
# Out:
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done  98 out of 105 | elapsed:    5.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    5.8s finished
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  98 out of 105 | elapsed:    3.0s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    3.2s finished
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  98 out of 105 | elapsed:    4.2s remaining:    0.3s
# CPU times: user 950 ms, sys: 830 ms, total: 1.78 s
# Wall time: 14 s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    4.4s finished

# %% [markdown]
# Optimize SVC

# %%
clfSVC=SVC(random_state=42)
#param_clfSVC=({'clf__C':np.logspace(-3,3,7),
#              'clf__kernel':['rbf']})
param_clfSVC=({'clf__C':range(10,100,10),
               'clf__kernel':['rbf']})

# %%
# %%time
ds='Sample1_SVC'
results=run_models(ds,X,y,clfSVC, param_clfSVC,pca=0)

model_scores=pd.concat([model_scores,results],axis=0, ignore_index=True)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   49.3s finished
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   35.4s finished
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   36.8s finished
# CPU times: user 13.3 s, sys: 340 ms, total: 13.6 s
# Wall time: 2min 14s

# %%
# %%time
ds='Sample1_SVC_PC'
results=run_models(ds,X,y,clfSVC, param_clfSVC,pca=1)

model_scores=pd.concat([model_scores,results],axis=0, ignore_index=True)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   54.7s finished
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   35.1s finished
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:   38.8s finished
# CPU times: user 14.4 s, sys: 1.04 s, total: 15.5 s
# Wall time: 2min 23s

# %%
model_scores.sort_index(axis=1).sort_values('mean_test_score', ascending=False).head(10).T
# Out:
#                                                   17   \
# Dataset                                   Sample1_KNN
# featset                                          top5
# mean_fit_time                              0.00708237
# mean_score_time                             0.0331752
# mean_test_score                              0.802172
# mean_train_score                             0.843864
# param_clf__C                                      NaN
# param_clf__kernel                                 NaN
# param_clf__max_depth                              NaN
# param_clf__min_samples_split                      NaN
# param_clf__n_neighbors                              9
# param_clf__penalty                                NaN
# params                        {'clf__n_neighbors': 9}
# rank_test_score                                     1
# split0_test_score                            0.793618
# split0_train_score                           0.845188
# split1_test_score                            0.814664
# split1_train_score                           0.840435
# split2_test_score                            0.809912
# split2_train_score                           0.842472
# split3_test_score                            0.790903
# split3_train_score                           0.845697
# split4_test_score                            0.801765
# split4_train_score                           0.845527
# std_fit_time                              6.82068e-05
# std_score_time                            0.000454686
# std_test_score                              0.0091244
# std_train_score                            0.00207735
#
#                                                   51   \
# Dataset                                Sample1_KNN_PC
# featset                                         top10
# mean_fit_time                               0.0286974
# mean_score_time                             0.0922911
# mean_test_score                              0.801494
# mean_train_score                             0.852419
# param_clf__C                                      NaN
# param_clf__kernel                                 NaN
# param_clf__max_depth                              NaN
# param_clf__min_samples_split                      NaN
# param_clf__n_neighbors                              7
# param_clf__penalty                                NaN
# params                        {'clf__n_neighbors': 7}
# rank_test_score                                     1
# split0_test_score                            0.790903
# split0_train_score                           0.851978
# split1_test_score                            0.808554
# split1_train_score                            0.85028
# split2_test_score                            0.810591
# split2_train_score                           0.851808
# split3_test_score                            0.786151
# split3_train_score                           0.853675
# split4_test_score                             0.81127
# split4_train_score                           0.854354
# std_fit_time                                0.0106801
# std_score_time                              0.0284661
# std_test_score                              0.0107307
# std_train_score                            0.00144677
#
#                                                   53   \
# Dataset                                Sample1_KNN_PC
# featset                                         top10
# mean_fit_time                               0.0272942
# mean_score_time                             0.0618116
# mean_test_score                               0.80095
# mean_train_score                             0.846206
# param_clf__C                                      NaN
# param_clf__kernel                                 NaN
# param_clf__max_depth                              NaN
# param_clf__min_samples_split                      NaN
# param_clf__n_neighbors                              9
# param_clf__penalty                                NaN
# params                        {'clf__n_neighbors': 9}
# rank_test_score                                     2
# split0_test_score                             0.79905
# split0_train_score                           0.844339
# split1_test_score                            0.809912
# split1_train_score                            0.84332
# split2_test_score                            0.809912
# split2_train_score                           0.847564
# split3_test_score                            0.786151
# split3_train_score                           0.847225
# split4_test_score                            0.799728
# split4_train_score                           0.848583
# std_fit_time                                0.0103072
# std_score_time                              0.0217798
# std_test_score                              0.0087721
# std_train_score                             0.0020171
#
#                                                   16   \
# Dataset                                   Sample1_KNN
# featset                                          top5
# mean_fit_time                              0.00720382
# mean_score_time                             0.0323363
# mean_test_score                              0.799457
# mean_train_score                              0.84753
# param_clf__C                                      NaN
# param_clf__kernel                                 NaN
# param_clf__max_depth                              NaN
# param_clf__min_samples_split                      NaN
# param_clf__n_neighbors                              8
# param_clf__penalty                                NaN
# params                        {'clf__n_neighbors': 8}
# rank_test_score                                     2
# split0_test_score                            0.795655
# split0_train_score                           0.849092
# split1_test_score                            0.816701
# split1_train_score                           0.839925
# split2_test_score                            0.799728
# split2_train_score                           0.846546
# split3_test_score                            0.793618
# split3_train_score                           0.852317
# split4_test_score                            0.791582
# split4_train_score                           0.849771
# std_fit_time                              8.52436e-05
# std_score_time                            0.000897638
# std_test_score                             0.00903302
# std_train_score                            0.00422321
#
#                                                                317  \
# Dataset                                             Sample1_SVC_PC
# featset                                                      top10
# mean_fit_time                                               3.0463
# mean_score_time                                           0.148999
# mean_test_score                                           0.798914
# mean_train_score                                          0.835138
# param_clf__C                                                    90
# param_clf__kernel                                              rbf
# param_clf__max_depth                                           NaN
# param_clf__min_samples_split                                   NaN
# param_clf__n_neighbors                                         NaN
# param_clf__penalty                                             NaN
# params                        {'clf__C': 90, 'clf__kernel': 'rbf'}
# rank_test_score                                                  1
# split0_test_score                                         0.802444
# split0_train_score                                        0.833984
# split1_test_score                                         0.798371
# split1_train_score                                        0.837888
# split2_test_score                                         0.797692
# split2_train_score                                        0.833475
# split3_test_score                                         0.791582
# split3_train_score                                        0.834833
# split4_test_score                                         0.804481
# split4_train_score                                        0.835512
# std_fit_time                                              0.111834
# std_score_time                                          0.00621737
# std_test_score                                          0.00444969
# std_train_score                                          0.0015424
#
#                                                                315  \
# Dataset                                             Sample1_SVC_PC
# featset                                                      top10
# mean_fit_time                                              2.80039
# mean_score_time                                           0.154787
# mean_test_score                                           0.798914
# mean_train_score                                          0.831913
# param_clf__C                                                    70
# param_clf__kernel                                              rbf
# param_clf__max_depth                                           NaN
# param_clf__min_samples_split                                   NaN
# param_clf__n_neighbors                                         NaN
# param_clf__penalty                                             NaN
# params                        {'clf__C': 70, 'clf__kernel': 'rbf'}
# rank_test_score                                                  1
# split0_test_score                                         0.803123
# split0_train_score                                        0.829571
# split1_test_score                                         0.796334
# split1_train_score                                        0.835512
# split2_test_score                                         0.797692
# split2_train_score                                        0.830419
# split3_test_score                                         0.793618
# split3_train_score                                        0.833475
# split4_test_score                                         0.803802
# split4_train_score                                        0.830589
# std_fit_time                                             0.0743016
# std_score_time                                           0.0105248
# std_test_score                                          0.00394456
# std_train_score                                         0.00222988
#
#                                                   47   \
# Dataset                                Sample1_KNN_PC
# featset                                         top10
# mean_fit_time                               0.0200762
# mean_score_time                              0.049982
# mean_test_score                              0.798642
# mean_train_score                               0.8936
# param_clf__C                                      NaN
# param_clf__kernel                                 NaN
# param_clf__max_depth                              NaN
# param_clf__min_samples_split                      NaN
# param_clf__n_neighbors                              3
# param_clf__penalty                                NaN
# params                        {'clf__n_neighbors': 3}
# rank_test_score                                     3
# split0_test_score                            0.784793
# split0_train_score                           0.895434
# split1_test_score                             0.81127
# split1_train_score                           0.890511
# split2_test_score                             0.80516
# split2_train_score                           0.894755
# split3_test_score                            0.791582
# split3_train_score                           0.894415
# split4_test_score                            0.800407
# split4_train_score                           0.892887
# std_fit_time                               0.00641995
# std_score_time                              0.0211239
# std_test_score                              0.0094519
# std_train_score                            0.00175558
#
#                                                   26   \
# Dataset                                   Sample1_KNN
# featset                                         top10
# mean_fit_time                              0.00786071
# mean_score_time                              0.048823
# mean_test_score                              0.798642
# mean_train_score                             0.847598
# param_clf__C                                      NaN
# param_clf__kernel                                 NaN
# param_clf__max_depth                              NaN
# param_clf__min_samples_split                      NaN
# param_clf__n_neighbors                              9
# param_clf__penalty                                NaN
# params                        {'clf__n_neighbors': 9}
# rank_test_score                                     1
# split0_test_score                             0.79905
# split0_train_score                           0.846885
# split1_test_score                            0.797013
# split1_train_score                           0.849941
# split2_test_score                            0.801086
# split2_train_score                           0.846715
# split3_test_score                            0.805838
# split3_train_score                           0.846546
# split4_test_score                            0.790224
# split4_train_score                           0.847904
# std_fit_time                              0.000135435
# std_score_time                            0.000508899
# std_test_score                             0.00512728
# std_train_score                            0.00126302
#
#                                                   52   \
# Dataset                                Sample1_KNN_PC
# featset                                         top10
# mean_fit_time                               0.0295886
# mean_score_time                              0.101944
# mean_test_score                              0.798371
# mean_train_score                             0.846919
# param_clf__C                                      NaN
# param_clf__kernel                                 NaN
# param_clf__max_depth                              NaN
# param_clf__min_samples_split                      NaN
# param_clf__n_neighbors                              8
# param_clf__penalty                                NaN
# params                        {'clf__n_neighbors': 8}
# rank_test_score                                     4
# split0_test_score                            0.790903
# split0_train_score                           0.845697
# split1_test_score                            0.806517
# split1_train_score                            0.84366
# split2_test_score                            0.803123
# split2_train_score                           0.846546
# split3_test_score                            0.783435
# split3_train_score                           0.849941
# split4_test_score                            0.807875
# split4_train_score                           0.848752
# std_fit_time                                0.0113936
# std_score_time                             0.00879893
# std_test_score                             0.00957206
# std_train_score                             0.0022247
#
#                                                                316
# Dataset                                             Sample1_SVC_PC
# featset                                                      top10
# mean_fit_time                                              3.01255
# mean_score_time                                           0.169133
# mean_test_score                                           0.798099
# mean_train_score                                          0.833441
# param_clf__C                                                    80
# param_clf__kernel                                              rbf
# param_clf__max_depth                                           NaN
# param_clf__min_samples_split                                   NaN
# param_clf__n_neighbors                                         NaN
# param_clf__penalty                                             NaN
# params                        {'clf__C': 80, 'clf__kernel': 'rbf'}
# rank_test_score                                                  3
# split0_test_score                                         0.802444
# split0_train_score                                        0.831438
# split1_test_score                                         0.797692
# split1_train_score                                         0.83653
# split2_test_score                                         0.798371
# split2_train_score                                        0.831947
# split3_test_score                                         0.792261
# split3_train_score                                        0.834663
# split4_test_score                                         0.799728
# split4_train_score                                        0.832626
# std_fit_time                                              0.101085
# std_score_time                                           0.0327411
# std_test_score                                          0.00334244
# std_train_score                                         0.00189452

# %%
model_scores.to_pickle('./data/pickle_data/Sample1_model_scores')

# %%
m_check=pd.read_pickle('./data/pickle_data/Sample1_model_scores')

# %%
m_check.equals(model_scores)
# Out:
# True

# %%
fig=plt.figure(figsize=(15,8))
sns.boxplot(x=model_scores['featset'], y=model_scores['mean_test_score'],\
            hue=model_scores['Dataset'])
plt.legend(loc=4)
plt.title('Boxplot of best test scores for each model')
plt.tight_layout()
plt.savefig('./images/03-Model_Selection-samples-modelscores_boxplot.jpg')
